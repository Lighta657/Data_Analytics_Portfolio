# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
import matplotlib.ticker as mtick

#Natural Language Toolkit/TextBlob
import re
import nltk as nlt
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from textblob import TextBlob

from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn import metrics
from sklearn.metrics import classification_report

from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier

nlt.download('punkt')
nlt.download('stopwords')
nlt.download('wordnet')

# Handle date time conversions between pandas and matplotlib
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %matplotlib inline
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# </div>

# %%
# File location and type
file_location = "/FileStore/tables/rawtweets4.csv"
file_type = "csv"

# CSV options
infer_schema = "false"
first_row_is_header = "false"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>_c1</th><th>_c2</th><th>_c3</th><th>_c4</th><th>_c5</th></tr></thead><tbody><tr><td>4</td><td>1985419430</td><td>Sun May 31 17:04:02 PDT 2009</td><td>NO_QUERY</td><td>themoderngal</td><td>@roxyreeb You need a new hobby. Wanna train for a triathlon with me? </td></tr><tr><td>4</td><td>1985419460</td><td>Sun May 31 17:04:02 PDT 2009</td><td>NO_QUERY</td><td>rachfran</td><td>loooves my friends, and as of today loves the chillness of sundays! </td></tr><tr><td>4</td><td>1985419474</td><td>Sun May 31 17:04:02 PDT 2009</td><td>NO_QUERY</td><td>giiirly</td><td>the hills  last one D:</td></tr><tr><td>4</td><td>1985419514</td><td>Sun May 31 17:04:02 PDT 2009</td><td>NO_QUERY</td><td>ilovepushplaay</td><td>teamviewer is entertaining </td></tr><tr><td>4</td><td>1985419535</td><td>Sun May 31 17:04:03 PDT 2009</td><td>NO_QUERY</td><td>folieameghan</td><td>i intensely miss my bestfriends! much love!!  [two more days]</td></tr><tr><td>4</td><td>1985419536</td><td>Sun May 31 17:04:03 PDT 2009</td><td>NO_QUERY</td><td>misfitsxgurl138</td><td>Watching the Hills season finale!!! Can't wait for the world premier of the New Moon clip!!!! </td></tr><tr><td>4</td><td>1985419568</td><td>Sun May 31 17:04:03 PDT 2009</td><td>NO_QUERY</td><td>asribour</td><td>The Hills and MTV music awards  what a way to end my weekend!</td></tr><tr><td>4</td><td>1985419672</td><td>Sun May 31 17:04:03 PDT 2009</td><td>NO_QUERY</td><td>Zweibz7</td><td>@KempEquine thanks  It was a lot of fun!</td></tr><tr><td>4</td><td>1985419724</td><td>Sun May 31 17:04:04 PDT 2009</td><td>NO_QUERY</td><td>MizzTxNy</td><td>@JerZDre nothin much doin' the same--&gt;its a Sunday I feel like I'm breaking a rule by doin' anything today besides chill </td></tr><tr><td>4</td><td>1985419725</td><td>Sun May 31 17:04:04 PDT 2009</td><td>NO_QUERY</td><td>Zweibz7</td><td>@KempEquine thanks  It was a lot of fun!</td></tr><tr><td>4</td><td>1985419727</td><td>Sun May 31 17:04:04 PDT 2009</td><td>NO_QUERY</td><td>kikiharestad</td><td>is lovin the sun </td></tr><tr><td>4</td><td>1985419753</td><td>Sun May 31 17:04:04 PDT 2009</td><td>NO_QUERY</td><td>DianeLovesJB</td><td>just one hour left to the awards  ... watchin' the red carpet right now! @ashleytisdale u look amazing </td></tr><tr><td>4</td><td>1985419759</td><td>Sun May 31 17:04:04 PDT 2009</td><td>NO_QUERY</td><td>ChristophRawrr</td><td>80.6 Fahrenheit tomorrow  Going to the beach  this has been the most amazing week its seldom every warm in Scotland</td></tr><tr><td>4</td><td>1985419793</td><td>Sun May 31 17:04:04 PDT 2009</td><td>NO_QUERY</td><td>justyesterday</td><td>@gypsymoondesign Way to go!  I am more than 100 photos behind.... I should stop twittering and get started </td></tr><tr><td>4</td><td>1985419800</td><td>Sun May 31 17:04:04 PDT 2009</td><td>NO_QUERY</td><td>danieldryzek</td><td>After 1.5 years I am bact to TRAFFIC domain conference, cool  This time in Amsterdam about ccTLDs. http://targetedtraffic.com</td></tr><tr><td>4</td><td>1985419813</td><td>Sun May 31 17:04:04 PDT 2009</td><td>NO_QUERY</td><td>lisastarlynn</td><td>@freewebaddress Thanks for the follow! </td></tr><tr><td>4</td><td>1985419896</td><td>Sun May 31 17:04:05 PDT 2009</td><td>NO_QUERY</td><td>gardenJess</td><td>Just had green tea and honey.  Was calming, and waking all at once.  </td></tr><tr><td>4</td><td>1985419916</td><td>Sun May 31 17:04:05 PDT 2009</td><td>NO_QUERY</td><td>fashionxjunkie</td><td>bought a touchscreen camera today.  now at the theater watching up 3D.</td></tr><tr><td>4</td><td>1985419936</td><td>Sun May 31 17:04:05 PDT 2009</td><td>NO_QUERY</td><td>lixyb</td><td>wow, Nadal's out of the #frenchopen... !!!?!?! GOOOO FEDS, the door's wide open!!!!! </td></tr><tr><td>4</td><td>1985419947</td><td>Sun May 31 17:04:07 PDT 2009</td><td>NO_QUERY</td><td>Amador323</td><td>no plans.. might go out for a walk on sunset blvd and en ...

# %%
# Create a view or table

#temp_table_name = "rawtweets1_csv"

#df.createOrReplaceTempView(temp_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# With this registered as a temp view, it will only be available to this particular notebook. If you'd like other users to be able to query this table, you can also create a table from the DataFrame.
# Once saved, this table will persist across cluster restarts as well as allow various users across different notebooks to query this data.
# To do so, choose your table name and uncomment the bottom line.

#permanent_table_name = "rawtweets_csv"

#df.write.format("parquet").saveAsTable(permanent_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>_c1</th><th>_c2</th><th>_c3</th><th>_c4</th><th>_c5</th></tr></thead><tbody><tr><td>4</td><td>1985419430</td><td>Sun May 31 17:04:02 PDT 2009</td><td>NO_QUERY</td><td>themoderngal</td><td>@roxyreeb You need a new hobby. Wanna train for a triathlon with me? </td></tr><tr><td>4</td><td>1985419460</td><td>Sun May 31 17:04:02 PDT 2009</td><td>NO_QUERY</td><td>rachfran</td><td>loooves my friends, and as of today loves the chillness of sundays! </td></tr><tr><td>4</td><td>1985419474</td><td>Sun May 31 17:04:02 PDT 2009</td><td>NO_QUERY</td><td>giiirly</td><td>the hills  last one D:</td></tr><tr><td>4</td><td>1985419514</td><td>Sun May 31 17:04:02 PDT 2009</td><td>NO_QUERY</td><td>ilovepushplaay</td><td>teamviewer is entertaining </td></tr><tr><td>4</td><td>1985419535</td><td>Sun May 31 17:04:03 PDT 2009</td><td>NO_QUERY</td><td>folieameghan</td><td>i intensely miss my bestfriends! much love!!  [two more days]</td></tr><tr><td>4</td><td>1985419536</td><td>Sun May 31 17:04:03 PDT 2009</td><td>NO_QUERY</td><td>misfitsxgurl138</td><td>Watching the Hills season finale!!! Can't wait for the world premier of the New Moon clip!!!! </td></tr><tr><td>4</td><td>1985419568</td><td>Sun May 31 17:04:03 PDT 2009</td><td>NO_QUERY</td><td>asribour</td><td>The Hills and MTV music awards  what a way to end my weekend!</td></tr><tr><td>4</td><td>1985419672</td><td>Sun May 31 17:04:03 PDT 2009</td><td>NO_QUERY</td><td>Zweibz7</td><td>@KempEquine thanks  It was a lot of fun!</td></tr><tr><td>4</td><td>1985419724</td><td>Sun May 31 17:04:04 PDT 2009</td><td>NO_QUERY</td><td>MizzTxNy</td><td>@JerZDre nothin much doin' the same--&gt;its a Sunday I feel like I'm breaking a rule by doin' anything today besides chill </td></tr><tr><td>4</td><td>1985419725</td><td>Sun May 31 17:04:04 PDT 2009</td><td>NO_QUERY</td><td>Zweibz7</td><td>@KempEquine thanks  It was a lot of fun!</td></tr><tr><td>4</td><td>1985419727</td><td>Sun May 31 17:04:04 PDT 2009</td><td>NO_QUERY</td><td>kikiharestad</td><td>is lovin the sun </td></tr><tr><td>4</td><td>1985419753</td><td>Sun May 31 17:04:04 PDT 2009</td><td>NO_QUERY</td><td>DianeLovesJB</td><td>just one hour left to the awards  ... watchin' the red carpet right now! @ashleytisdale u look amazing </td></tr><tr><td>4</td><td>1985419759</td><td>Sun May 31 17:04:04 PDT 2009</td><td>NO_QUERY</td><td>ChristophRawrr</td><td>80.6 Fahrenheit tomorrow  Going to the beach  this has been the most amazing week its seldom every warm in Scotland</td></tr><tr><td>4</td><td>1985419793</td><td>Sun May 31 17:04:04 PDT 2009</td><td>NO_QUERY</td><td>justyesterday</td><td>@gypsymoondesign Way to go!  I am more than 100 photos behind.... I should stop twittering and get started </td></tr><tr><td>4</td><td>1985419800</td><td>Sun May 31 17:04:04 PDT 2009</td><td>NO_QUERY</td><td>danieldryzek</td><td>After 1.5 years I am bact to TRAFFIC domain conference, cool  This time in Amsterdam about ccTLDs. http://targetedtraffic.com</td></tr><tr><td>4</td><td>1985419813</td><td>Sun May 31 17:04:04 PDT 2009</td><td>NO_QUERY</td><td>lisastarlynn</td><td>@freewebaddress Thanks for the follow! </td></tr><tr><td>4</td><td>1985419896</td><td>Sun May 31 17:04:05 PDT 2009</td><td>NO_QUERY</td><td>gardenJess</td><td>Just had green tea and honey.  Was calming, and waking all at once.  </td></tr><tr><td>4</td><td>1985419916</td><td>Sun May 31 17:04:05 PDT 2009</td><td>NO_QUERY</td><td>fashionxjunkie</td><td>bought a touchscreen camera today.  now at the theater watching up 3D.</td></tr><tr><td>4</td><td>1985419936</td><td>Sun May 31 17:04:05 PDT 2009</td><td>NO_QUERY</td><td>lixyb</td><td>wow, Nadal's out of the #frenchopen... !!!?!?! GOOOO FEDS, the door's wide open!!!!! </td></tr><tr><td>4</td><td>1985419947</td><td>Sun May 31 17:04:07 PDT 2009</td><td>NO_QUERY</td><td>Amador323</td><td>no plans.. might go out for a walk on sunset blvd and en ...

# %%
df=df.toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df1=df.iloc[0:3,:]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;pandas.core.frame.DataFrame&#39;&gt;
# RangeIndex: 400000 entries, 0 to 399999
# Data columns (total 6 columns):
# _c0    400000 non-null object
# _c1    400000 non-null object
# _c2    400000 non-null object
# _c3    400000 non-null object
# _c4    400000 non-null object
# _c5    400000 non-null object
# dtypes: object(6)
# memory usage: 18.3+ MB
# </div>

# %%
rawtweets4=rawtweets3.append(df1, ignore_index=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rawtweets=df.copy()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# EDA

# %%
rawtweets4.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;pandas.core.frame.DataFrame&#39;&gt;
# RangeIndex: 1600000 entries, 0 to 1599999
# Data columns (total 6 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   _c0     1600000 non-null  object
#  1   _c1     1600000 non-null  object
#  2   _c2     1600000 non-null  object
#  3   _c3     1600000 non-null  object
#  4   _c4     1600000 non-null  object
#  5   _c5     1600000 non-null  object
# dtypes: object(6)
# memory usage: 73.2+ MB
# </div>

# %%
tweets=rawtweets4.copy()
#tweets=rawtweets.sample(20000,axis=0)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Rename columns
old_col=['_c0','_c1','_c2','_c3','_c4','_c5']
new_col=['Label','ID','Date','Query','User','Text']
tweets[new_col]=tweets[old_col]
tweets=tweets.drop(old_col,axis=1)
tweets.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Label</th>
#       <th>ID</th>
#       <th>Date</th>
#       <th>Query</th>
#       <th>User</th>
#       <th>Text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1467810369</td>
#       <td>Mon Apr 06 22:19:45 PDT 2009</td>
#       <td>NO_QUERY</td>
#       <td>_TheSpecialOne_</td>
#       <td>@switchfoot http://twitpic.com/2y1zl - Awww, t...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>1467810672</td>
#       <td>Mon Apr 06 22:19:49 PDT 2009</td>
#       <td>NO_QUERY</td>
#       <td>scotthamilton</td>
#       <td>is upset that he can't update his Facebook by ...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>1467810917</td>
#       <td>Mon Apr 06 22:19:53 PDT 2009</td>
#       <td>NO_QUERY</td>
#       <td>mattycus</td>
#       <td>@Kenichan I dived many times for the ball. Man...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0</td>
#       <td>1467811184</td>
#       <td>Mon Apr 06 22:19:57 PDT 2009</td>
#       <td>NO_QUERY</td>
#       <td>ElleCTF</td>
#       <td>my whole body feels itchy and like its on fire</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0</td>
#       <td>1467811193</td>
#       <td>Mon Apr 06 22:19:57 PDT 2009</td>
#       <td>NO_QUERY</td>
#       <td>Karoli</td>
#       <td>@nationwideclass no, it's not behaving at all....</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#Format Date
tweets['Date']=pd.to_datetime(tweets['Date'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.7/site-packages/dateutil/parser/_parser.py:1206: UnknownTimezoneWarning: tzname PDT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# </div>

# %%
tweets['Date'].dt.tz_localize('America/Los_Angeles')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[50]: 0         2009-04-06 22:19:45-07:00
# 1         2009-04-06 22:19:49-07:00
# 2         2009-04-06 22:19:53-07:00
# 3         2009-04-06 22:19:57-07:00
# 4         2009-04-06 22:19:57-07:00
# 5         2009-04-06 22:20:00-07:00
# 6         2009-04-06 22:20:03-07:00
# 7         2009-04-06 22:20:03-07:00
# 8         2009-04-06 22:20:05-07:00
# 9         2009-04-06 22:20:09-07:00
# 10        2009-04-06 22:20:16-07:00
# 11        2009-04-06 22:20:17-07:00
# 12        2009-04-06 22:20:19-07:00
# 13        2009-04-06 22:20:19-07:00
# 14        2009-04-06 22:20:20-07:00
# 15        2009-04-06 22:20:20-07:00
# 16        2009-04-06 22:20:22-07:00
# 17        2009-04-06 22:20:25-07:00
# 18        2009-04-06 22:20:31-07:00
# 19        2009-04-06 22:20:34-07:00
# 20        2009-04-06 22:20:37-07:00
# 21        2009-04-06 22:20:38-07:00
# 22        2009-04-06 22:20:40-07:00
# 23        2009-04-06 22:20:40-07:00
# 24        2009-04-06 22:20:41-07:00
# 25        2009-04-06 22:20:44-07:00
# 26        2009-04-06 22:20:50-07:00
# 27        2009-04-06 22:20:52-07:00
# 28        2009-04-06 22:20:56-07:00
# 29        2009-04-06 22:21:04-07:00
#                      ...
# 1599970   2009-06-16 08:38:55-07:00
# 1599971   2009-06-16 08:38:55-07:00
# 1599972   2009-06-16 08:38:55-07:00
# 1599973   2009-06-16 08:38:55-07:00
# 1599974   2009-06-16 08:38:55-07:00
# 1599975   2009-06-16 08:38:55-07:00
# 1599976   2009-06-16 08:38:57-07:00
# 1599977   2009-06-16 08:38:56-07:00
# 1599978   2009-06-16 08:38:57-07:00
# 1599979   2009-06-16 08:38:57-07:00
# 1599980   2009-06-16 08:38:57-07:00
# 1599981   2009-06-16 08:38:57-07:00
# 1599982   2009-06-16 08:38:58-07:00
# 1599983   2009-06-16 08:38:58-07:00
# 1599984   2009-06-16 08:38:58-07:00
# 1599985   2009-06-16 08:38:59-07:00
# 1599986   2009-06-16 08:38:59-07:00
# 1599987   2009-06-16 08:38:59-07:00
# 1599988   2009-06-16 08:38:59-07:00
# 1599989   2009-06-16 08:39:00-07:00
# 1599990   2009-06-16 08:39:00-07:00
# 1599991   2009-06-16 08:39:00-07:00
# 1599992   2009-06-16 08:40:49-07:00
# 1599993   2009-06-16 08:40:49-07:00
# 1599994   2009-06-16 08:40:49-07:00
# 1599995   2009-06-16 08:40:49-07:00
# 1599996   2009-06-16 08:40:50-07:00
# 1599997   2009-05-31 17:04:02-07:00
# 1599998   2009-05-31 17:04:02-07:00
# 1599999   2009-05-31 17:04:02-07:00
# Name: Date, Length: 1600000, dtype: datetime64[ns, America/Los_Angeles]</div>

# %%
tweets.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[27]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Label</th>
#       <th>ID</th>
#       <th>Date</th>
#       <th>Query</th>
#       <th>User</th>
#       <th>Text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1467810369</td>
#       <td>Mon Apr 06 22:19:45 PDT 2009</td>
#       <td>NO_QUERY</td>
#       <td>_TheSpecialOne_</td>
#       <td>@switchfoot http://twitpic.com/2y1zl - Awww, t...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>1467810672</td>
#       <td>Mon Apr 06 22:19:49 PDT 2009</td>
#       <td>NO_QUERY</td>
#       <td>scotthamilton</td>
#       <td>is upset that he can't update his Facebook by ...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>1467810917</td>
#       <td>Mon Apr 06 22:19:53 PDT 2009</td>
#       <td>NO_QUERY</td>
#       <td>mattycus</td>
#       <td>@Kenichan I dived many times for the ball. Man...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0</td>
#       <td>1467811184</td>
#       <td>Mon Apr 06 22:19:57 PDT 2009</td>
#       <td>NO_QUERY</td>
#       <td>ElleCTF</td>
#       <td>my whole body feels itchy and like its on fire</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0</td>
#       <td>1467811193</td>
#       <td>Mon Apr 06 22:19:57 PDT 2009</td>
#       <td>NO_QUERY</td>
#       <td>Karoli</td>
#       <td>@nationwideclass no, it's not behaving at all....</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#tweets=tweets.assign(Count=1)

# %%
def form_sentence (tweet):
    tweet_blob=TextBlob(tweet)
    return ''.join(tweet_blob.words)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(form_sentence(tweets['Text'].iloc[12]))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">caregivingIcouldn&#39;tbeartowatchitAndIthoughttheUAlosswasembarrassing
# </div>

# %%
print(tweets['Text'].iloc[12])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">@caregiving I couldn&#39;t bear to watch it.  And I thought the UA loss was embarrassing . . . . .
# </div>

# %%
#Tokenizer (single string)
def no_user_alpha(tweet):
    tweet_list=[ele for ele in tweet.split() if ele !='user']
    clean_tokens=[t for t in tweet_list if
                re.match(r'[^\W\d]*$',t)]
    clean_s=''.join(clean_tokens)
    clean_mess=[word for word in clean_s.split() if word.lower() not in stopwords.words('english')]
    return clean_tokens
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(no_user_alpha(tweets['Text'].iloc[12]))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;I&#39;, &#39;bear&#39;, &#39;to&#39;, &#39;watch&#39;, &#39;And&#39;, &#39;I&#39;, &#39;thought&#39;, &#39;the&#39;, &#39;UA&#39;, &#39;loss&#39;, &#39;was&#39;, &#39;embarrassing&#39;]
# </div>

# %%
#Lemmatizer
def normalization(tweet_list):
    lem=WordNetLemmatizer()
    normalized_tweet=[]
    for word in tweet_list:
        normalized_text=lem.lemmatize(word,'v')
        normalized_tweet.append(normalized_text)
        return normalized_tweet
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(normalization(tweets['Text'].iloc[12].split()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;@caregiving&#39;]
# </div>

# %%
pipeline=Pipeline([
    ('bow',CountVectorizer(analyzer='word',stop_words='english')), #quantify text contents by word
    ('tfidf',TfidfTransformer()), #weighted TF-IDF scores
    ('classifier', KNeighborsClassifier(n_neighbors=3)), #train on TF-IDF vectors w SVC
])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
X_train, X_test, y_train, y_test=train_test_split(tweets['Text'],tweets['Label'],test_size=0.2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pipeline.fit(X_train,y_train)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: Pipeline(memory=None,
#          steps=[(&#39;bow&#39;,
#                  CountVectorizer(analyzer=&#39;word&#39;, binary=False,
#                                  decode_error=&#39;strict&#39;,
#                                  dtype=&lt;class &#39;numpy.int64&#39;&gt;, encoding=&#39;utf-8&#39;,
#                                  input=&#39;content&#39;, lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=1,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=&#39;english&#39;, strip_accents=None,
#                                  token_pattern=&#39;(?u)\\b\\w\\w+\\b&#39;,
#                                  tokenizer=None, vocabulary=None)),
#                 (&#39;tfidf&#39;,
#                  TfidfTransformer(norm=&#39;l2&#39;, smooth_idf=True,
#                                   sublinear_tf=False, use_idf=True)),
#                 (&#39;classifier&#39;,
#                  KNeighborsClassifier(algorithm=&#39;auto&#39;, leaf_size=30,
#                                       metric=&#39;minkowski&#39;, metric_params=None,
#                                       n_jobs=None, n_neighbors=3, p=2,
#                                       weights=&#39;uniform&#39;))],
#          verbose=False)</div>

# %%
preds=pipeline.predict(X_test)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
print(classification_report(preds,y_test))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">              precision    recall  f1-score   support
#
#            0       0.37      0.80      0.50     72979
#            4       0.91      0.59      0.72    247021
#
#    micro avg       0.64      0.64      0.64    320000
#    macro avg       0.64      0.70      0.61    320000
# weighted avg       0.79      0.64      0.67    320000
#
# </div>

# %%
plt.figure()

# Add the models to the list that you want to view on the ROC plot
models = [
{
      'label': 'Support Vector Classifier',
      'model': SVC(probability=True)
},
{
    'label': 'Gradient Boosting',
    'model': GradientBoostingClassifier(n_estimators=50)
},
{
    'label': 'Random Forest',
    'model': RandomForestClassifier(n_estimators=50)
}
]
    
# Below for loop iterates through your models list
for m in models:
    model = m['model'] # select the model
    label = m['label'] # select the label
    
    pipeline=Pipeline([
    ('bow',CountVectorizer(analyzer='word',stop_words='english')), #quantify text contents by word
    ('tfidf',TfidfTransformer()), #weighted TF-IDF scores
    (label, model), #train on TF-IDF vectors w SVC
    ])
    
    pipeline.fit(X_train, y_train) # train the model
    y_pred=pipeline.predict(X_test)# predict the test data

    # Compute False postive rate, and True positive rate
    fpr, tpr, thresholds = metrics.roc_curve(y_test, pipeline.predict_proba(X_test)[:,1], pos_label=4)

    # Calculate Area under the curve to display on the plot
    auc = metrics.roc_auc_score(y_test,pipeline.predict(X_test))

    # Now, plot the computed values
    plt.plot(fpr, tpr, label='%s ROC (area = %0.2f)' % (m['label'], auc))

    # Custom settings for the plot 
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.07])
plt.ylim([0.0, 1.05])
plt.xlabel('1-Specificity (False Positive Rate)')
plt.ylabel('Sensitivity (True Positive Rate)')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="best")
plt.show()   # Display
